# %%
# only for test

import csv
import glob, os
import pandas as pd

print('aa')
print(os.path.abspath('.'))
# Out:
# aa
# C:\Users\mynam\Documents\GitHub\Video-Player-Controlled-by-Action-Recognition_wkr\src

# %%
# initialisation
# TODO: move all packages here but not for now

featureDict = {'down': {} , 'up': {}, 'left': {}, 'right': {}, 'fist': {}}

# %%
# load data from csv files
# feature extraction
# TODO: freq-domain features
# TODO: feature selection
# TODO: normalisation

import math
import numpy as np
import csv
import glob, os
import pandas as pd

# locate folers
actionList = ['down', 'up', 'left', 'right', 'fist']
for currentAction in range(len(actionList)):
    filePath1 = os.path.abspath('./Dataset/hyqData/' + actionList[currentAction])
    filePath2 = os.path.abspath('./Dataset/zjhData/' + actionList[currentAction])
    filePath3 = os.path.abspath('./Dataset/sgfData/' + actionList[currentAction])
#     filePath4 = os.path.abspath('./Dataset/znData/' + actionList[currentAction])

    print('Loading action: ' + actionList[currentAction])


    file1 = glob.glob(os.path.join(filePath1, "*.csv"))
    file2 = glob.glob(os.path.join(filePath2, "*.csv"))
    file3 = glob.glob(os.path.join(filePath3, "*.csv"))
#     file4 = glob.glob(os.path.join(filePath4, "*.csv"))


    dl = []
    for f in file1:
        dl.append(pd.read_csv(f, header=None))
    for f in file2:
        dl.append(pd.read_csv(f, header=None))
    for f in file3:
        dl.append(pd.read_csv(f, header=None))
#     for f in file4:
#         dl.append(pd.read_csv(f, header=None))



    # obtain each EMG channel data
    emg_1=[]
    emg_2=[]
    emg_3=[]

    featureList = []

    index=0
    i=0
    for index in range(len(dl)): # access all csv files

        for i in range(len(dl[index].values.tolist())): # access all recorded samples
            emg_1.append(dl[index].values.tolist()[i][0])
            emg_2.append(dl[index].values.tolist()[i][1])
            emg_3.append(dl[index].values.tolist()[i][2])


        ### calculate time-domain features

        # Mean Absolute Value
        MAV_emg_1 = 0
        MAV_emg_2 = 0
        MAV_emg_3 = 0
        # Wavelength
        WL_emg_1 = 0
        WL_emg_2 = 0
        WL_emg_3 = 0
        # Slope Sign Changes
        SSCthreshold = 0 # TODO: detemine the threshold
        SSC_emg_1 = 0
        SSC_emg_2 = 0
        SSC_emg_3 = 0
        # Zero Crossing: we don't have, do we?
        ZC_emg_1 = 0
        ZC_emg_2 = 0
        ZC_emg_3 = 0
        # Root Mean Square
        RMS_emg_1 = 0.0
        RMS_emg_2 = 0.0
        RMS_emg_3 = 0.0

        i=0
        temp1=0
        temp2=0
        temp3=0
        temp4=0
        temp5=0
        temp6=0
        temp7=0.0
        temp8=0.0
        temp9=0.0
        for i in range(len(emg_3)):
            temp1 = temp1 + abs(int(emg_1[i]))
            temp2 = temp2 + abs(int(emg_2[i]))
            temp3 = temp3 + abs(int(emg_3[i]))
            temp7 = temp7 + (int(emg_1[i]))**2
            temp8 = temp8 + (int(emg_2[i]))**2
            temp9 = temp9 + (int(emg_3[i]))**2

            if(i>0):
                WL_emg_1 = WL_emg_1 + abs(int(emg_1[i]) - int(emg_1[i-1]))
                WL_emg_2 = WL_emg_2 + abs(int(emg_2[i]) - int(emg_2[i-1]))
                WL_emg_3 = WL_emg_3 + abs(int(emg_3[i]) - int(emg_3[i-1]))

            if(i>1):
                temp4 = (int(emg_1[i-1]) - int(emg_1[i-2])) * (int(emg_1[i-1]) - int(emg_1[i]))
                temp5 = (int(emg_2[i-1]) - int(emg_2[i-2])) * (int(emg_2[i-1]) - int(emg_2[i]))
                temp6 = (int(emg_3[i-1]) - int(emg_3[i-2])) * (int(emg_3[i-1]) - int(emg_3[i]))
                if temp4 >= SSCthreshold:
                    SSC_emg_1 = SSC_emg_1 + 1
                if temp5 >= SSCthreshold:
                    SSC_emg_2 = SSC_emg_2 + 1
                if temp6 >= SSCthreshold:
                    SSC_emg_3 = SSC_emg_3 + 1



            MAV_emg_1 = temp1/len(emg_1)
            MAV_emg_2 = temp2/len(emg_2)
            MAV_emg_3 = temp3/len(emg_3)

            RMS_emg_1 = math.sqrt(temp7/len(emg_1))
            RMS_emg_2 = math.sqrt(temp8/len(emg_2))
            RMS_emg_3 = math.sqrt(temp9/len(emg_3))

        featureDict[actionList[currentAction]][index] = [MAV_emg_1, MAV_emg_2, MAV_emg_3, WL_emg_1, WL_emg_2, WL_emg_3, SSC_emg_1, SSC_emg_2, SSC_emg_3, RMS_emg_1, RMS_emg_2, RMS_emg_3]

print('Loading completed')

    # print(MAV_emg_1, MAV_emg_2, MAV_emg_3)
    # print(WL_emg_1, WL_emg_2, WL_emg_3)
    # print(SSC_emg_1, SSC_emg_2, SSC_emg_3)
    # print(RMS_emg_1, RMS_emg_2, RMS_emg_3)
# Out:
# Loading action: down
# Loading action: up
# Loading action: left
# Loading action: right
# Loading action: fist
# Loading completed

# %%
# TODO: feature selection
# TODO: visualisation (if possible)

print(featureDict.keys())
print(len(featureDict['down']))
print(len(featureDict['up']))
print(len(featureDict['left']))
print(len(featureDict['right']))
print(len(featureDict['fist']))
print(featureDict['down'][0])
print(featureDict['up'][0])
print(featureDict['left'][0])
print(featureDict['right'][0])
print(featureDict['fist'][0])
# Out:
# dict_keys(['down', 'up', 'left', 'right', 'fist'])
# 75
# 70
# 69
# 70
# 75
# [39.693333333333335, 55.17666666666667, 74.89666666666666, 499, 522, 1652, 219, 196, 215, 46.753894668430206, 64.37931862536809, 170.15286264611203]
# [17.243333333333332, 171.14, 105.74333333333334, 40, 1030, 610, 297, 147, 157, 17.271460081108756, 216.06070134725258, 131.5700700514115]
# [52.26, 71.05666666666667, 18.476666666666667, 964, 774, 168, 227, 198, 255, 85.64395289024594, 101.17929630117023, 27.522899556551085]
# [59.38, 72.19, 59.7, 966, 705, 1261, 195, 174, 232, 76.48424674401913, 85.48288327690716, 137.3561550616984]
# [58.67666666666667, 118.07333333333334, 32.553333333333335, 1285, 1341, 802, 226, 168, 234, 103.38170373265604, 130.02540777350657, 53.41891050929436]

# %%
# create labels for data samples

from keras.utils import np_utils
x_val=[]
y_val=[]

def labelSwitch(arg):
    switcher = {
        'left': 1,
        'right': 2,
        'up': 3,
        'down': 4,
        'fist': 5
    }
    return switcher[arg]

i=0
j=''
dictLength=0
current = ['down', 'up', 'left', 'right', 'fist']
for j in range(len(current)):
    for i in range(len(featureDict[current[j]])):
        x_val.append(featureDict[current[j]][i])
        y_val.append(labelSwitch(current[j]))
        dictLength=dictLength+1

x_val_array = np.array(x_val)
y_val_array = np.array(y_val).reshape(dictLength,1)


state = np.random.get_state()
np.random.shuffle(x_val_array)
np.random.set_state(state)
np.random.shuffle(y_val_array)


TRAIN_SPLIT = int(0.6*x_val_array.shape[0])
TEST_SPLIT = int(0.2*x_val_array.shape[0] + TRAIN_SPLIT)


x_train, x_test, x_validate = np.split(x_val_array, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_val_array, [TRAIN_SPLIT, TEST_SPLIT])



y_train_class = np_utils.to_categorical(y_train)
y_test_class = np_utils.to_categorical(y_test)
y_validate_class = np_utils.to_categorical(y_validate)


#  see dataset volume

print(x_train.shape)
print(y_train_class.shape)
print(x_validate.shape)
print(y_validate_class.shape)
print(x_test.shape)
print(y_test_class.shape)




# TODO: Model

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
tf.random.set_seed(1234)

model = Sequential()

model.add(Dense(12, activation='relu', input_shape=(x_train.shape)))
model.add(Dense(50, activation='relu'))
# model.add(Dropout(0.1))
model.add(Dense(50, activation='relu'))
# model.add(Dropout(0.1))
model.add(Dense(6, activation='softmax'))

# opt = RMSprop(lr=0.1, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train_class, epochs=50, batch_size=50, validation_data=(x_validate, y_validate_class))

# Plot training accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (215, 12)
# (215, 6)
# (73, 12)
# (73, 6)
# (71, 12)
# (71, 6)
# Epoch 1/50
# 5/5 [==============================] - 0s 42ms/step - loss: 14034.5723 - accuracy: 0.2233 - val_loss: 9250.1553 - val_accuracy: 0.1644
# Epoch 2/50
# 5/5 [==============================] - 0s 5ms/step - loss: 7490.8018 - accuracy: 0.2558 - val_loss: 5412.5264 - val_accuracy: 0.1781
# Epoch 3/50
# 5/5 [==============================] - 0s 5ms/step - loss: 3784.2620 - accuracy: 0.1488 - val_loss: 2480.1611 - val_accuracy: 0.1507
# Epoch 4/50
# 5/5 [==============================] - 0s 6ms/step - loss: 1945.5797 - accuracy: 0.1302 - val_loss: 1344.5648 - val_accuracy: 0.2466
# Epoch 5/50
# 5/5 [==============================] - 0s 5ms/step - loss: 1171.0216 - accuracy: 0.2140 - val_loss: 1059.9766 - val_accuracy: 0.2740
# Epoch 6/50
# 5/5 [==============================] - 0s 5ms/step - loss: 678.4022 - accuracy: 0.3163 - val_loss: 413.9647 - val_accuracy: 0.5479
# Epoch 7/50
# 5/5 [==============================] - 0s 5ms/step - loss: 322.8158 - accuracy: 0.4837 - val_loss: 245.6472 - val_accuracy: 0.5616
# Epoch 8/50
# 5/5 [==============================] - 0s 6ms/step - loss: 208.2495 - accuracy: 0.5163 - val_loss: 156.2688 - val_accuracy: 0.5753
# Epoch 9/50
# 5/5 [==============================] - 0s 5ms/step - loss: 142.2377 - accuracy: 0.6279 - val_loss: 132.9626 - val_accuracy: 0.6986
# Epoch 10/50
# 5/5 [==============================] - 0s 5ms/step - loss: 107.6828 - accuracy: 0.7023 - val_loss: 86.0169 - val_accuracy: 0.6849
# Epoch 11/50
# 5/5 [==============================] - 0s 6ms/step - loss: 90.4225 - accuracy: 0.6977 - val_loss: 63.2695 - val_accuracy: 0.7123
# Epoch 12/50
# 5/5 [==============================] - 0s 5ms/step - loss: 75.7463 - accuracy: 0.7023 - val_loss: 48.6930 - val_accuracy: 0.7123
# Epoch 13/50
# 5/5 [==============================] - 0s 5ms/step - loss: 58.8439 - accuracy: 0.6884 - val_loss: 42.4826 - val_accuracy: 0.7397
# Epoch 14/50
# 5/5 [==============================] - 0s 5ms/step - loss: 42.9539 - accuracy: 0.7116 - val_loss: 28.1145 - val_accuracy: 0.7397
# Epoch 15/50
# 5/5 [==============================] - 0s 5ms/step - loss: 28.2478 - accuracy: 0.7116 - val_loss: 20.8453 - val_accuracy: 0.7397
# Epoch 16/50
# 5/5 [==============================] - 0s 5ms/step - loss: 31.1349 - accuracy: 0.7581 - val_loss: 30.6582 - val_accuracy: 0.7123
# Epoch 17/50
# 5/5 [==============================] - 0s 5ms/step - loss: 24.7220 - accuracy: 0.8000 - val_loss: 28.2195 - val_accuracy: 0.6849
# Epoch 18/50
# 5/5 [==============================] - 0s 6ms/step - loss: 20.1267 - accuracy: 0.7907 - val_loss: 28.2322 - val_accuracy: 0.8219
# Epoch 19/50
# 5/5 [==============================] - 0s 5ms/step - loss: 22.2646 - accuracy: 0.7907 - val_loss: 15.9333 - val_accuracy: 0.7397
# Epoch 20/50
# 5/5 [==============================] - 0s 5ms/step - loss: 14.4052 - accuracy: 0.7953 - val_loss: 36.7887 - val_accuracy: 0.8219
# Epoch 21/50
# 5/5 [==============================] - 0s 5ms/step - loss: 27.3508 - accuracy: 0.8372 - val_loss: 38.5642 - val_accuracy: 0.7123
# Epoch 22/50
# 5/5 [==============================] - 0s 5ms/step - loss: 25.9243 - accuracy: 0.8372 - val_loss: 14.2228 - val_accuracy: 0.7808
# Epoch 23/50
# 5/5 [==============================] - 0s 5ms/step - loss: 16.1668 - accuracy: 0.8419 - val_loss: 14.7063 - val_accuracy: 0.7397
# Epoch 24/50
# 5/5 [==============================] - 0s 5ms/step - loss: 10.8149 - accuracy: 0.8326 - val_loss: 26.2084 - val_accuracy: 0.8082
# Epoch 25/50
# 5/5 [==============================] - 0s 5ms/step - loss: 26.7673 - accuracy: 0.7860 - val_loss: 32.1095 - val_accuracy: 0.8219
# Epoch 26/50
# 5/5 [==============================] - 0s 5ms/step - loss: 41.3073 - accuracy: 0.7721 - val_loss: 56.1273 - val_accuracy: 0.7123
# Epoch 27/50
# 5/5 [==============================] - 0s 5ms/step - loss: 36.8245 - accuracy: 0.8093 - val_loss: 97.2966 - val_accuracy: 0.8356
# Epoch 28/50
# 5/5 [==============================] - 0s 5ms/step - loss: 63.4281 - accuracy: 0.8047 - val_loss: 113.0873 - val_accuracy: 0.6849
# Epoch 29/50
# 5/5 [==============================] - 0s 6ms/step - loss: 69.2825 - accuracy: 0.7767 - val_loss: 58.7191 - val_accuracy: 0.7945
# Epoch 30/50
# 5/5 [==============================] - 0s 5ms/step - loss: 55.7559 - accuracy: 0.7860 - val_loss: 126.3651 - val_accuracy: 0.6438
# Epoch 31/50
# 5/5 [==============================] - 0s 5ms/step - loss: 111.4924 - accuracy: 0.7349 - val_loss: 155.8107 - val_accuracy: 0.5753
# Epoch 32/50
# 5/5 [==============================] - 0s 5ms/step - loss: 169.0618 - accuracy: 0.7256 - val_loss: 84.7111 - val_accuracy: 0.8356
# Epoch 33/50
# 5/5 [==============================] - 0s 5ms/step - loss: 82.5566 - accuracy: 0.7442 - val_loss: 43.7928 - val_accuracy: 0.6986
# Epoch 34/50
# 5/5 [==============================] - 0s 5ms/step - loss: 72.7890 - accuracy: 0.7070 - val_loss: 46.7690 - val_accuracy: 0.7534
# Epoch 35/50
# 5/5 [==============================] - 0s 5ms/step - loss: 57.1670 - accuracy: 0.8047 - val_loss: 70.0398 - val_accuracy: 0.6849
# Epoch 36/50
# 5/5 [==============================] - 0s 5ms/step - loss: 29.0632 - accuracy: 0.8419 - val_loss: 49.0294 - val_accuracy: 0.7534
# Epoch 37/50
# 5/5 [==============================] - 0s 5ms/step - loss: 32.5745 - accuracy: 0.8186 - val_loss: 44.7822 - val_accuracy: 0.6849
# Epoch 38/50
# 5/5 [==============================] - 0s 5ms/step - loss: 21.7231 - accuracy: 0.8419 - val_loss: 18.9350 - val_accuracy: 0.7671
# Epoch 39/50
# 5/5 [==============================] - 0s 5ms/step - loss: 42.0383 - accuracy: 0.8186 - val_loss: 42.6088 - val_accuracy: 0.7534
# Epoch 40/50
# 5/5 [==============================] - 0s 5ms/step - loss: 76.3253 - accuracy: 0.7767 - val_loss: 20.8261 - val_accuracy: 0.7671
# Epoch 41/50
# 5/5 [==============================] - 0s 5ms/step - loss: 59.3506 - accuracy: 0.7767 - val_loss: 32.5051 - val_accuracy: 0.7397
# Epoch 42/50
# 5/5 [==============================] - 0s 6ms/step - loss: 40.2225 - accuracy: 0.8140 - val_loss: 41.2047 - val_accuracy: 0.7123
# Epoch 43/50
# 5/5 [==============================] - 0s 7ms/step - loss: 33.6424 - accuracy: 0.7953 - val_loss: 32.9172 - val_accuracy: 0.7534
# Epoch 44/50
# 5/5 [==============================] - 0s 5ms/step - loss: 23.0720 - accuracy: 0.8140 - val_loss: 16.6744 - val_accuracy: 0.7671
# Epoch 45/50
# 5/5 [==============================] - 0s 5ms/step - loss: 12.6582 - accuracy: 0.8558 - val_loss: 20.6547 - val_accuracy: 0.7808
# Epoch 46/50
# 5/5 [==============================] - 0s 5ms/step - loss: 10.3387 - accuracy: 0.8744 - val_loss: 12.6718 - val_accuracy: 0.7808
# Epoch 47/50
# 5/5 [==============================] - 0s 5ms/step - loss: 9.5248 - accuracy: 0.8791 - val_loss: 13.2216 - val_accuracy: 0.7671
# Epoch 48/50
# 5/5 [==============================] - 0s 5ms/step - loss: 21.1864 - accuracy: 0.8372 - val_loss: 69.2757 - val_accuracy: 0.7123
# Epoch 49/50
# 5/5 [==============================] - 0s 5ms/step - loss: 40.6988 - accuracy: 0.8140 - val_loss: 63.4128 - val_accuracy: 0.8356
# Epoch 50/50
# 5/5 [==============================] - 0s 5ms/step - loss: 45.4108 - accuracy: 0.8233 - val_loss: 98.8166 - val_accuracy: 0.6986
# Test loss: 43.96471405029297
# Test accuracy: 0.8450704216957092
